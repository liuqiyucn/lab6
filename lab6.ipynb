# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
I_D = np.array([0.716
,0.7159
,0.7145
,0.7122
,0.7101
,0.7068
,0.7041
,0.6999
,0.6945
,0.6889
,0.6829
,0.6227
,0.6684])
V_DS = np.array([11.04
,11.03
,9.82
,8.05
,6.75
,5.101
,4.069
,2.925
,1.975
,1.396
,1.035
,0.345
,0.649
])

# %%
plt.plot(V_DS, I_D,'o')
plt.ylabel(r'$I_D$ [mA]')
plt.xlabel(r'$V_{DS}$ [V]')
plt.savefig('6-2 V_DS.png')
plt.show()

# %%
V_GS = [-2.01,-2.1,-2.502,-3.017,-3.601,-4.018,-4.544,-1.888,-1.744,-1.494,-4.651,-4.758,-4.809] 
I_D = [6.49,6.185,4.781,3.148,1.564,0.683,0.057,6.92,7.452,8.396,0.022,0.006,0.003] 
I_D = np.array(I_D)* 10**-3
plt.plot(V_GS, np.log10(I_D), 'o')
plt.ylabel('log(I_d) [log(A)]')
plt.xlabel('V_GS [V]' )
plt.savefig("transistor1.png")
plt.show()

# %%
V_GS = [-2.047,-2.426,-2.825,-3.022,-3.075,-3.142,-3.251,-3.515,-4.029] 
I_D = [1.689,0.743,0.123,0.02,0.01,0.004,0.003,0.001,0.001] 
I_D = np.array(I_D)* 10**-3
plt.plot(V_GS, np.log10(I_D), 'o')
plt.ylabel('log(I_d) [log(A)]')
plt.xlabel('V_GS [V]' )
plt.savefig("transistor2.png")
plt.show()

# %%
V_GS = [-2.042,-2.528,-3.1,-3.56,-4.326,-4.854,-3.665,-3.855,-3.967,-4.166]
I_D = [6.455,4.726,2.933,1.696,0.253,0.003,1.4371,1.0192,0.7999,0.4588]
I_D = np.array(I_D)*10**-3
plt.plot(V_GS, np.log10(I_D), 'o')
plt.ylabel('log(I_d) [log(A)]')
plt.xlabel('V_GS [V]' )
plt.savefig("transistor3.png")
plt.show()
